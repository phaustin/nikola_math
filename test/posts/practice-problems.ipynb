# %% [markdown]
# # 1. Conservation of energy -- day 3

# %% [markdown]
# ### P1.1: (Day 3) Equilibrium walls
#
# Two walls are at the same temperature, so there is no net flux between the walls.  Assume the transmissivities of the walls are 0.  How much flux is absorbed at wall A?
#
# **Ans: **Fluxes must balance at the wall in equillibrium, so absorption = 209 $W\,m^{-2}$

# %%
Image('wallq1.png',width="30%")
#Figure 1.1

# %% [markdown]
# ### P1.2: For Figure 1.1:  How much flux is absorbed at the right wall?

# %% [markdown]
# **Ans: **350 $W\,m^{-2}$ is emitted so 350 $W\,m^{-2}$ must be absorbed.

# %% [markdown]
# ### P1.3: For Figure 1.1:  What is the absorprtivity of the left wall?

# %% [markdown]
# **Ans: **Kirchoff's law says $abs=\epsilon$ = 0.6

# %% [markdown]
# ### P1.4: For Figure 1.1: What is the reflectivity of the left wall?

# %% [markdown]
# **Ans: **The wall is not transmitting, so ref = 1 - abs = 0.4

# %% [markdown]
# # 2. Layers -- Day 5

# %% [markdown]
# ### P2.1: 3.	Stacked layers:
#
# Four layers of glass have equal emissivities ε and don't reflect any light.  If the emissivity of each layer is 0.2, what is the total transmissivity of the four layers

# %% [markdown]
# abs= $\epsilon$ = 0.2 so trans = 1 - 0.2 = 0.8
#
# **Ans: ** transmissivities multiply, so Trtot = 0.41

# %%
Trtot = 0.8**4.
print(Trtot)
# Out:
# 0.4096000000000001

# %% [markdown]
# ### P2.2:  Black atmosphere 1
#
# The following figure shows an atmosphere that is black (ε=1) in the long wave, transparent in the visible, over a surface that has ε=1 in both long wave and visible.  If the average incident solar intensity Iin = 340 $W\,m^{-2}$, what is the temperature of the atmosphere?

# %%
Image('four_layers.png',width="30%")

# %% [markdown]
# **Ans: **$I_a$ = -340 $W m^{-2}$ to balance $I_{in}$ so the black atmosphere has
# to be at $T_a = (340/\sigma)^{1/4}$ = 278.3 K

# %%
(340/sigma)**0.25
# Out:
# 278.2748546226214

# %% [markdown]
# ### P2.3:  ground flux
#
# Referring to the figure above, what is the magnitude of Ig?  ($Wm^{-2}$)

# %% [markdown]
# **Ans: **To balance both $I_{in}$ and $I_a$, $I_g$ needs to be 680 $W\,m^{-2}$

# %% [markdown]
# # 3. Partially transmitting layers

# %%
Image('two_layer.png',width='40%')

# %% [markdown]
# ### P3.1
#
# For the figure above, assume no shortwave absorption, a black surface, and
# longwave emissivities $\epsilon_1$ and $\epsilon_2$ as shown.
# If the surface flux is 403 $W\,m^{-2}$ and the flux from layer 1 is
# 139 $W\,m^{-2}$, what temperature does Layer 2 have to be to maintain
# equilibrium?

# %% [markdown]
# ### P3.2
#
# Suppose layer 2 had a temperature of 230 K.  What is it's heating/cooling rate in $W\,m^{-1}$?

# %% [markdown]
# ### P3.3
#
# Suppose layer 2 had an average temperature 230 K, with level B at a pressure of 50 kPa (kiloPascals)
# and and level C at a pressure of 0 kPa.   What is the E, the column energy for the layer, in $J\,m^{-2}$

# %% [markdown]
# ### P3.4
#
# How long would it take a net downward flux of 4 $W\,m^{-2}$ to raise the average temperature
# of a 2 km thick ocean layer by 1 K?
